# %%
# Om Vighna Ganapathi
# Om Vighna Ganapathi
# Om Vighna Ganapathi Namo Namaha

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
6
# Out:
# 6

# %%
9 + 9
# Out:
# 18

# %%
9 + 9 -(10 * 3) - 3
# Out:
# -15

# %%
9 + 9 - 10 * 3 - 3
# Out:
# -15

# %%
9 + 9 - (10 -3) + 3
# Out:
# 14

# %%
9 + 9 - 10 - 3 + 3
# Out:
# 8

# %% [markdown]
# # **Arithmetic** **Operators**

# %%
10 + 5
# Out:
# 15

# %%
10 - 5
# Out:
# 5

# %%
10 * 5
# Out:
# 50

# %%
10 * 2 # Multiplication
# Out:
# 20

# %%
10 ** 2 # Power
# Out:
# 100

# %%
10 *** 2
# Out:
#   File "/tmp/ipython-input-2368405663.py", line 1
#     10 *** 2
#          ^
# SyntaxError: invalid syntax

# %%
10 / 5 # Float Division
# Out:
# 2.0

# %%
10 // 5 # Int Division
# Out:
# 2

# %%
10 % 5 # Modulus - returns the remainder after dividing
# Out:
# 0

# %%
15 % 2
# Out:
# 1

# %%
15 % 6
# Out:
# 3

# %%
15 / 6
# Out:
# 2.5

# %%
15 // 6
# Out:
# 2

# %%
2 ^ 5
# Out:
# 7

# %%
x = 10
x
# Out:
# 10

# %%
2 ^ 1
# Out:
# 3

# %%
2 ^ 2
# Out:
# 0

# %%
x + 2
# Out:
# 12

# %%
x + 2
# Out:
# 12

# %%
x + 2
# Out:
# 12

# %%
x += 2
x
# Out:
# 14

# %%
x += 2
x
# Out:
# 16

# %%
x += 2
x
# Out:
# 18

# %%
x += 2
x
# Out:
# 20

# %%
x -= 2
x
# Out:
# 18

# %%
x -= 2

# %%
x
# Out:
# 16

# %%
x -= 2
x
# Out:
# 14

# %%
x -= 2
x
# Out:
# 12

# %%
x *= 2
x
# Out:
# 24

# %%
x *= 2
x
# Out:
# 48

# %%
x /= 2
x
# Out:
# 24.0

# %%
x //= 2
x
# Out:
# 12.0

# %%
x // 2
# Out:
# 6.0

# %% [markdown]
# # Unary Operator

# %%
n = 7
n
# Out:
# 7

# %%
m = -(n)
m
# Out:
# -7

# %%
n
# Out:
# 7

# %%
num = 5
res = ~num
res
# Out:
# -6

# %%
n = 7
r = ~n
r
# Out:
# -8
